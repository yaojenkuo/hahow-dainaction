# %% [markdown]
# # 如何成為資料分析師
#
# > 爬取 Indeed/CakeResume/104 資料分析師職缺描述。
#
# [數據交點](https://datainpoint.substack.com/welcome) | 郭耀仁 <yaojenkuo@datainpoint.com>

# %%
import random
import re
import time
import requests
from bs4 import BeautifulSoup
import pandas as pd
from indeed_scraper import IndeedJobDescScraper
from cake_resume_scraper import CakeResumeJobDescScraper
from one_o_four_scraper import OneOFourJobDescScraper

# %%
indeed_job_desc_scraper = IndeedJobDescScraper("資料分析師", 5)
cake_resume_job_desc_scraper = CakeResumeJobDescScraper("資料分析師", 5)
one_o_four_job_desc_scraper = OneOFourJobDescScraper("資料分析師")
indeed_jd = indeed_job_desc_scraper.get_job_descriptions()
cake_resume_jd = cake_resume_job_desc_scraper.get_job_descriptions()
one_o_four_jd = one_o_four_job_desc_scraper.get_job_descriptions()
# Out:
# Scraping page 1...
# Scraping page 2...
# Scraping page 3...
# Scraping page 4...
# Scraping page 5...
# 正在爬取Hahow的人力資源管理師 Human Resources Specialist工作描述...
# 正在爬取台灣之星電信股份有限公司的03_大數據科學家工作描述...
# 正在爬取英屬安吉拉商多重宙有限公司的專案管理師 Project Manager (具備數據思維)工作描述...
# 正在爬取Dentsu Aegis Network的Data Analyst - CRO/CDP工作描述...
# 正在爬取國泰金控的Bank / 行政人力資源數據分析師工作描述...
# 正在爬取國泰金控的Bank / 數據生態營運資料科學分析師 -數據分析 (數數發中心,DDT)工作描述...
# 正在爬取國泰金控的Bank / 新興金融數據暨客群經營分析師工作描述...
# 正在爬取國泰金控的Sec / 2021校徵商業分析師工作描述...
# 正在爬取國泰金控的Bank / 數據生態營運風險數據分析師(數數發中心, DDT)工作描述...
# 正在爬取意藍資訊 eLand的A2-客戶分析師 (客戶關係經營、產品問題諮詢)工作描述...
# 正在爬取iCHEF的iCHEF QA 品保工程師 / 品質分析師工作描述...
# 正在爬取國泰金控的Bank / 數據生態營運資料科學分析師 -數據應用 (數數發中心,DDT)工作描述...
# 正在爬取親子天下的會員經營專員/資深專員工作描述...
# 正在爬取國泰金控的Life / 中台系統分析師工作描述...
# 正在爬取Gogolook (Whoscall)的Data Engineer / Data Analyst工作描述...
# 正在爬取iCHEF的客戶成長規劃師工作描述...
# 正在爬取GoSky AI Inc.的廣告優化師 Digital Advertising Analyst工作描述...
# 正在爬取長庚醫療財團法人的土城醫院外傷中心招募定期契約外傷登錄師工作描述...
# 正在爬取鮮乳坊的商品管理專員工作描述...
# ...

# %%
data_analyst_jd = pd.concat([indeed_jd, cake_resume_jd, one_o_four_jd])
data_analyst_jd.to_excel("data_analyst_jd.xlsx", index=False)
