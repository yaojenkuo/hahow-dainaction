# %%
import pandas as pd
import matplotlib.pyplot as plt
from ks2020 import KaggleSurvey2020

# %%
csv_file = "kaggle_survey_2020_responses.csv"
ks = KaggleSurvey2020(csv_file)

# %%
unique_questions = ks.generate_unique_questions()
unique_questions[unique_questions["question_index"].isin(["Q7", "Q8", "Q9", "Q14", "Q16", "Q23", "Q29A", "Q31A"])]
# Out:
#    question_index                                      question_desc  \
# 6              Q7  What programming languages do you use on a reg...
# 7              Q8  What programming language would you recommend ...
# 8              Q9  Which of the following integrated development ...
# 13            Q14  What data visualization libraries or tools do ...
# 15            Q16  Which of the following machine learning framew...
# 22            Q23  Select any activities that make up an importan...
# 28           Q29A  Which of the following big data products (rela...
# 30           Q31A  Which of the following business intelligence t...
#
#          question_type
# 6   multiple selection
# 7      multiple choice
# 8   multiple selection
# 13  multiple selection
# 15  multiple selection
# 22  multiple selection
# 28  multiple selection
# 30  multiple selection

# %%
ks.plot_summary('Q7')
# Out:
# What programming languages do you use on a regular basis? (Select all that apply)
# Too many categories, only showing the top 10.

# %%
ks.plot_summary('Q8')
# Out:
# What programming language would you recommend an aspiring data scientist to learn first?
# Too many categories, only showing the top 10.

# %%
ks.plot_summary('Q9')
# Out:
# Which of the following integrated development environments (IDE's) do you use on a regular basis?  (Select all that apply)
# Too many categories, only showing the top 10.

# %%
ks.plot_summary('Q14')
# Out:
# What data visualization libraries or tools do you use on a regular basis?  (Select all that apply)
# Too many categories, only showing the top 10.

# %%
ks.plot_summary('Q16')
# Out:
# Which of the following machine learning frameworks do you use on a regular basis? (Select all that apply)
# Too many categories, only showing the top 10.

# %%
ks.plot_summary('Q23')
# Out:
# Select any activities that make up an important part of your role at work: (Select all that apply)

# %%
ks.plot_summary('Q29A')
# Out:
# Which of the following big data products (relational databases, data warehouses, data lakes, or similar) do you use on a regular basis? (Select all that apply)
# Too many categories, only showing the top 10.

# %%
ks.plot_summary('Q31A')
# Out:
# Which of the following business intelligence tools do you use on a regular basis? (Select all that apply)
# Too many categories, only showing the top 10.
